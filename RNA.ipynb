# %%
dna="..."

# %%
dna_list=list(dna)

# %%
rna_list=[]

# %%
for i, item in enumerate(dna_list):
    if item=="T":
        rna_list.insert(i,"U")
    else:
        rna_list.insert(i,item)
        
print(''.join(rna_list))
# Out:
# ...
