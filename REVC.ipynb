# %%
dna="..."

# %%
dna_reverse=list(reversed(dna))
reverse_complement=[]

# %%
for i, item in enumerate(dna_reverse):
    if item=="T":
        reverse_complement.insert(i,"A")
    elif item=="A":
        reverse_complement.insert(i,"T")
    elif item=="C":
        reverse_complement.insert(i,"G")
    else:
        reverse_complement.insert(i,"C")

# %%
print(''.join(reverse_complement))
# Out:
# ...
